# %%
# so why lear to scrape websites?
# if you want to hone your ds skills, play around with data, do a pet project, you need 
# a dataset. There are plenty of datasets around on kaggle, government websites etc
# and you can come up with plenty of questions that can be answered using those dataset
# but what if you're interested in a specific subject/question and there's no data for
# it? sometimes you'd be able to get them by web-scraping


# scraping websites is an (extremely) iterative process
# basic workflow:
# 1. find the data you want on the web
# 2. inspect the webpages, identify the elements that you want
# 3. write code to parse the elements


# you'd start small and test code on one page but when you start implementing your code
# on other pages, often times you'll find that you have to modify your code to generalize
# well; compartmentalize code to keep it clean and manageable
# so I'm gonna go through how i scraped data on one page then show you how it fit into
# the entire workflow

# another point i want to mention is that I'm scraping a static page. I'll talk about
# scraping interactive javascript-rendered websites at the end

# if anybody has any suggestions, comments, questions, better ways of doing things,
# please feel free to let me know

# %%
# useful links:
# https://www.w3schools.com/html/html_basic.asp
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
# this is part of a project i'm doing, build a recommender system for skincare products
# for this, i need to have a dataset of users ratings of skincare products and the
# characteristics of users

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import bs4
from bs4 import BeautifulSoup
import time
import re
import math
import string
import collections
import dill
from requests_futures.sessions import FuturesSession
from retrying import retry

# %% [markdown]
# # 1. Scrape static websites using Requests and BeautifulSoup

# %%
# my goal is to get the name of the product, the general info of the product, then for
# user ratings, i want to get username, their rating, the date, age, skin, hair, eyes

# https://www.makeupalley.com/product/searching.asp?Brand=&BrandName=&CategoryID=709&title=

demo_link = 'https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream'
# most of the websites are html files. And html files are just text files with special
# markup.
# we'll use the requests package to the webpage and get the content of the webpage
r = requests.get(demo_link)
html_doc = r.text

# %%
# this is the webpage we saw in raw text form
html_doc
# Out:
# '<!DOCTYPE html><html><head>\t<meta charset="utf-8">\t<title>StriVectin TL Tightening Neck Cream reviews, photo, ingredients  - Makeupalley</title>\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\t\t\t<meta property="fb:app_id" content="225670347474872" />\t<meta property="og:site_name" content="MakeupAlley" />\t<meta name="robots" content="index,follow" /><meta name="robots" content="noarchive" /><meta name="googlebot" content="noarchive" />\t<meta property="og:url" content="https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" /> <meta property="og:type"   content="article" /> <meta property="og:title" content="StriVectin TL Tightening Neck Cream reviews, photo, ingredients" />\r\n<meta property="og:description" content="StriVectin  TL Tightening Neck Cream: rated 2.6 out of 5 on MakeupAlley.  See 19 member reviews,  ingredients and photo." />\r\n<meta property="og:image" content="https://img.makeupalley.com/fb/0_2_6_2_2336028.JPG" />\r\n<link rel="next"  href="/product/showreview.asp/ItemID=151441/page=2/"><link rel="alternate" hreflang="x-default" href="https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" /><link rel="alternate" hreflang="cs" href="http://www.makeupalley.cz/q/krem-na-krk-a-dekolt/strivectin-tl-tightening-neck-cream-recenze/151441" /><link rel="alternate" hreflang="da" href="http://www.makeupalley.dk/q/creme-til-halsbrystet-og-kavalergangen/strivectin-tl-tightening-neck-cream-anmeldelser/151441" /><link rel="alternate" hreflang="de-at" href="http://www.makeupalley.at/q/halsdekollete-creme/strivectin-tl-tightening-neck-cream-bewertungen/151441" /><link rel="alternate" hreflang="es" href="http://www.makeupalley.es/q/crema-de-cuelloescote/strivectin-tl-tightening-neck-cream-opiniones/151441" /><link rel="alternate" hreflang="es-mx" href="http://www.makeupalley.mx/q/crema-de-cuelloescote/strivectin-tl-tightening-neck-cream-opiniones/151441" /><link rel="alternate" hreflang="fr" href="http://www.makeupalley.fr/q/cremedecolletecou/strivectin-tl-tightening-neck-cream-avis/151441" /><link rel="alternate" hreflang="it" href="http://www.makeupalley.it/q/crema-collodecollete/strivectin-tl-tightening-neck-cream-recensioni/151441" /><link rel="alternate" hreflang="nl" href="http://nl.makeupalley.eu/q/hals-&-decollete-creme/strivectin-tl-tightening-neck-cream-beoordelingen/151441" /><link rel="alternate" hreflang="pl" href="http://www.makeupalley.pl/q/krem-do-szyidekoltu/strivectin-tl-tightening-neck-cream-opinie/151441" /><link rel="alternate" hreflang="pt" href="http://www.makeupalley.pt/q/creme-pescocodecote/strivectin-tl-tightening-neck-cream-rever/151441" /><link rel="alternate" hreflang="ru" href="http://www.makeupalley.com.ru/q/krem-dlya-sheidekol\'te/strivectin-tl-tightening-neck-cream-otzyvy/151441" /><meta name="description" content="StriVectin  TL Tightening Neck Cream: rated 2.6 out of 5 on MakeupAlley.  See 19 member reviews,  ingredients and photo."/>\t\t\t\t<style>/* _common.css */html {    font-family: sans-serif;}body {    margin: 0;}article, aside, details, figcaption, figure, footer, header, hgroup, main, nav, section, summary {    display: block;}a {    background: rgba(0, 0, 0, 0) none repeat scroll 0 0;}a:active, a:hover {    outline: 0 none;}b, strong {    font-weight: 700;}h1 {    font-size: 2em;    margin: 0.67em 0;}img {    border: 0 none;}hr {    box-sizing: content-box;    height: 0;}button, input, optgroup, select, textarea {    color: inherit;    font: inherit;    margin: 0;}button {    overflow: visible;}button, select {    text-transform: none;}button, html input[type="button"], input[type="reset"], input[type="submit"] {    cursor: pointer;}input {    line-height: normal;}input[type="checkbox"], input[type="radio"] {    box-sizing: border-box;    padding: 0;}* {    box-sizing: border-box;}*::before, *::after {    box-sizing: bor ...

# %%
# in order to make sense of the structure, we'll use BeautifulSoup to parse this text
# into a html tree form
soup = BeautifulSoup(html_doc, "html5lib")

# %%
print(soup.prettify())
# beautiful soup has parsed the html structure, tags, elements for us
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    StriVectin TL Tightening Neck Cream reviews, photo, ingredients  - Makeupalley
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="225670347474872" property="fb:app_id"/>
#   <meta content="MakeupAlley" property="og:site_name"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content="noarchive" name="googlebot"/>
#   <meta content="https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="StriVectin TL Tightening Neck Cream reviews, photo, ingredients" property="og:title"/>
#   <meta content="StriVectin  TL Tightening Neck Cream: rated 2.6 out of 5 on MakeupAlley.  See 19 member reviews,  ingredients and photo." property="og:description"/>
#   <meta content="https://img.makeupalley.com/fb/0_2_6_2_2336028.JPG" property="og:image"/>
#   <link href="/product/showreview.asp/ItemID=151441/page=2/" rel="next"/>
#   <link href="https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" hreflang="x-default" rel="alternate"/>
#   <link href="http://www.makeupalley.cz/q/krem-na-krk-a-dekolt/strivectin-tl-tightening-neck-cream-recenze/151441" hreflang="cs" rel="alternate"/>
#   <link href="http://www.makeupalley.dk/q/creme-til-halsbrystet-og-kavalergangen/strivectin-tl-tightening-neck-cream-anmeldelser/151441" hreflang="da" rel="alternate"/>
#   <link href="http://www.makeupalley.at/q/halsdekollete-creme/strivectin-tl-tightening-neck-cream-bewertungen/151441" hreflang="de-at" rel="alternate"/>
#   <link href="http://www.makeupalley.es/q/crema-de-cuelloescote/strivectin-tl-tightening-neck-cream-opiniones/151441" hreflang="es" rel="alternate"/>
#   <link href="http://www.makeupalley.mx/q/crema-de-cuelloescote/strivectin-tl-tightening-neck-cream-opiniones/151441" hreflang="es-mx" rel="alternate"/>
#   <link href="http://www.makeupalley.fr/q/cremedecolletecou/strivectin-tl-tightening-neck-cream-avis/151441" hreflang="fr" rel="alternate"/>
#   <link href="http://www.makeupalley.it/q/crema-collodecollete/strivectin-tl-tightening-neck-cream-recensioni/151441" hreflang="it" rel="alternate"/>
#   <link href="http://nl.makeupalley.eu/q/hals-&amp;-decollete-creme/strivectin-tl-tightening-neck-cream-beoordelingen/151441" hreflang="nl" rel="alternate"/>
#   <link href="http://www.makeupalley.pl/q/krem-do-szyidekoltu/strivectin-tl-tightening-neck-cream-opinie/151441" hreflang="pl" rel="alternate"/>
#   <link href="http://www.makeupalley.pt/q/creme-pescocodecote/strivectin-tl-tightening-neck-cream-rever/151441" hreflang="pt" rel="alternate"/>
#   <link href="http://www.makeupalley.com.ru/q/krem-dlya-sheidekol'te/strivectin-tl-tightening-neck-cream-otzyvy/151441" hreflang="ru" rel="alternate"/>
#   <meta content="StriVectin  TL Tightening Neck Cream: rated 2.6 out of 5 on MakeupAlley.  See 19 member reviews,  ingredients and photo." name="description"/>
#   <style>
#    /* _common.css */html {    font-family: sans-serif;}body {    margin: 0;}article, aside, details, figcaption, figure, footer, header, hgroup, main, nav, section, summary {    display: block;}a {    background: rgba(0, 0, 0, 0) none repeat scroll 0 0;}a:active, a:hover {    outline: 0 none;}b, strong {    font-weight: 700;}h1 {    font-size: 2em;    margin: 0.67em 0;}img {    border: 0 none;}hr {    box-sizing: content-box;    height: 0;}button, input, optgroup, select, textarea {    color: inherit;    font: inherit;    margin: 0;}button {    overflow: visible;}button, select {    text-transform: none;}button, html input[type="button"], input[type="reset"], input[type="submit"] {    cursor: pointer;}input {    line-height: normal;}input[type="checkbox"], input[type="radio"] {    box-sizing: border-box;    padding: 0;}* {    box-sizing: border-box;}*::before, *::after {    box-sizing: border-box;}html {    font-size: 10px;}body {    background-color: #fff;    color: #333;    font-family: "Helvetica Neue",Helvetica,Arial,sans-serif;    font-size: 14px;    line-height: 1.42857;}input, button, select, textarea {    font-family: inherit;    font-size: inherit;    line-height: inherit;}a {    color: #428bca;    text-decoration: none;}a:hover, a:focus {    color: #2a6496;    text-decoration: underline;}a:focus {    outline: thin dotted;    outline-offset: -2px;}img {    vertical-align: middle;}hr {    -moz-border-bottom-colors: none;    -moz-border-left-colors: none;    -moz-border-right-colors: none;    -moz-border-top-colors: none;    border-color: #eee -moz-use-text-color -moz-use-text-color;    border-image: none;    border-style: solid none none;    border-width: 1px 0 0;    margin-bottom: 20px;    margin-top: 20px;}.sr-only {    border: 0 none;    clip: rect(0px, 0px, 0px, 0px);    height: 1px;    margin: -1px;    overflow: hidden;    padding: 0;    position: absolute;    width: 1px;}h1, h2, h3, h4, h5, h6, .h1, .h2, .h3, .h4 {    color: inherit;    font-family: inherit;    font-weight: 500;    line-height: 1.1;}h1, .h1, h2, .h2, h3, .h3 {    margin-bottom: 10px;    margin-top: 20px;}h4, .h4 {    margin-bottom: 10px;    margin-top: 10px;}h1, .h1 {    font-size: 36px;}h2, .h2 {    font-size: 30px;}h3, .h3 {    font-size: 24px;}h4, .h4 {    font-size: 18px;}h5, .h5 {    font-size: 14px;}p {    margin: 0 0 10px;}@media (min-width: 768px) {ul, ol {    margin-bottom: 10px;    margin-top: 0;}ul ul, ol ul, ul ol, ol ol {    margin-bottom: 0;}.list-unstyled {    list-style: outside none none;    padding-left: 0;}}.container {    margin-left: auto;    margin-right: auto;    padding-left: 15px;    padding-right: 15px;}@media (min-width: 768px) {.container {    width: 750px;}}@media (min-width: 992px) {.container {    width: 970px;}}@media (min-width: 1200px) {.container {    width: 1170px;}}.row {    margin-left: -15px;    margin-right: -15px;}.col-xs-1, .col-sm-1, .col-md-1, .col-lg-1, .col-xs-2, .col-sm-2, .col-md-2, .col-lg-2, .col-xs-3, .col-sm-3, .col-md-3, .col-lg-3, .col-xs-4, .col-sm-4, .col-md-4, .col-lg-4, .col-xs-5, .col-sm-5, .col-md-5, .col-lg-5, .col-xs-6, .col-sm-6, .col-md-6, .col-lg-6, .col-xs-7, .col-sm-7, .col-md-7, .col-lg-7, .col-xs-8, .col-sm-8, .col-md-8, .col-lg-8, .col-xs-9, .col-sm-9, .col-md-9, .col-lg-9, .col-xs-10, .col-sm-10, .col-md-10, .col-lg-10, .col-xs-11, .col-sm-11, .col-md-11, .col-lg-11, .col-xs-12, .col-sm-12, .col-md-12, .col-lg-12 {    min-height: 1px;    padding-left: 15px;    padding-right: 15px;    position: relative;}.col-xs-1, .col-xs-2, .col-xs-3, .col-xs-4, .col-xs-5, .col-xs-6, .col-xs-7, .col-xs-8, .col-xs-9, .col-xs-10, .col-xs-11, .col-xs-12 {    float: left;}.col-xs-12 {    width: 100%;}.col-xs-11 {    width: 91.6667%;}.col-xs-10 {    width: 83.3333%;}.col-xs-9 {    width: 75%;}.col-xs-8 {    width: 66.6667%;}.col-xs-7 {    width: 58.3333%;}.col-xs-6 {    width: 50%;}.col-xs-5 {    width: 41.6667%;}.col-xs-4 {    width: 33.3333%;}.col-xs-3 {    width: 25%;}.col-xs-2 {    width: 16.6 ...
#   </style>
#   <script type="text/javascript">
#    var sDFPAds='REVIEWS_ATF-0,REVIEWS_ATF-1,REVIEWS_BTF-2,REVIEWS_BTF-3';
#   </script>
#   <script type="text/javascript">
#    var b;	function downloadJS() {	LoadIE();	JavaScript.load("//ajax.googleapis.com/ajax/libs/jquery/2.2.0/jquery.min.js", function()	{		JavaScript.load("/ScriptCombiner/ScriptCombiner.axd?s=/includes/js/html5/bootstrap.min.320.js,/includes/js/html5/lightbox.min.1.js,/includes/js/html5/typeahead-img.min.js,/includes/js/html5/jquery.sticky.js,/includes/js/html5/jquery.unveil.js,/includes/js/html5/mua.61.min.js",		function(){    });	});	}	function downloadCSS() {			if ( window.innerWidth>768)			{			CSS.load("//fonts.googleapis.com/css?family=Lato:700&amp;subset=latin,latin-ext",			function(){			});			}	}	var JavaScript = {  	load: function(src, callback) {    var script = document.createElement('script'),        loaded;    script.setAttribute('src', src);    if (callback) {      script.onreadystatechange = script.onload = function() {        if (!loaded) {          callback();        }        loaded = true;      };    }    document.getElementsByTagName('head')[0].appendChild(script);  	}	};	var CSS = {  	load: function(href, callback) {    var script = document.createElement('link'),        loaded;    	script.setAttribute('href', href);        script.setAttribute("rel", "stylesheet");        script.setAttribute("type", "text/css") ;   if (callback) {      script.onreadystatechange = script.onload = function() {        if (!loaded) {          callback();        }        loaded = true;      };    }    document.getElementsByTagName('head')[0].appendChild(script);  	}	};function LoadIE(){  if (b==1)  {  JavaScript.load("/includes/js/html5/html5shiv.min.js"); JavaScript.load("/includes/js/html5/respond.min.js"); }}downloadCSS();downloadJS();
#   </script>
#   <link href="/M32x32.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/art/fav/icon.57x57.png" rel="apple-touch-icon" type="image/png"/>
#   <link href="/art/fav/icon.72x72.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#   <link href="/art/fav/icon.114x114.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#   <link href="/art/fav/icon.114x114.png" rel="icon" type="image/png"/>
#   <link href="https://plus.google.com/+MakeupAlley" rel="publisher"/>
#   <link href="https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" rel="canonical"/>
#   <noscript>
#    <link href="//fonts.googleapis.com/css?family=Lato:700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   </noscript>
#  </head>
#  <body class="" id="topProducts">
#   <div class="container">
#    <div class="navbar navbar-default" role="navigation">
#     <div class="container-fluid">
#      <div id="membersOnline">
#       3568  Members Online
#      </div>
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <h1>
#        <a class="track_Nav_Home" href="/">
#         <img alt="MakeupAlley" class="discreet" height="51" src="/art/bs/Mua_Logo3x.png" width="247"/>
#        </a>
#       </h1>
#       <div data-target=".navbar-collapse-search" data-toggle="collapse" id="search">
#        <img alt="Search" height="36" src="/art/bs/icons/search.png" width="36"/>
#       </div>
#      </div>
#      <div class="navbar-collapse-search collapse">
#       <form action="/search.asp">
#        <div class="form-group">
#         <input id="q1" name="q" placeholder="Search" type="text" value=""/>
#         <input alt="Search" src="/art/bs/icons/search.png" type="image"/>
#        </div>
#       </form>
#      </div>
#      <div class="navbar-collapse collapse">
#       <ul class="nav navbar-nav">
#        <li class="active">
#         <a class="track_Nav_ProductReviews" href="/product/">
#          Product Reviews
#         </a>
#        </li>
#        <li>
#         <a class="track_Nav_Boards" href="/board/">
#          Boards
#         </a>
#        </li>
#        <li>
#         <a class="track_Nav_Mail" href="/mail/">
#          Mail
#         </a>
#        </li>
#        <li>
#         <a class="track_Nav_Favorites" href="/favorites/">
#          Favorites
#         </a>
#        </li>
#       </ul>
#       <ul class="nav navbar-nav navbar-right" id="userControlMenu">
#        <!-- NEW: mobile and other size -->
#        <li class="review-menu visible-xs-block">
#         <a aria-controls="collapseWriteReview" aria-expanded="false" data-toggle="collapse" href="#collapseWriteReviewXS">
#          <span class="spr-reviews">
#          </span>
#          <span class="visible-xs-block">
#           Review
#           <b class="caret">
#           </b>
#          </span>
#         </a>
#         <div aria-labelledby="headingOne" class="panel-collapse collapse writeReviewLookup" id="collapseWriteReviewXS" role="tabpanel">
#          <div class="panel-body">
#           <input autocomplete="off" class="form-control search-field typeahead" id="search-data-img" placeholder="Find a product to review" spellcheck="false" type="text"/>
#          </div>
#         </div>
#        </li>
#        <li class="review-menu hidden-xs">
#         <div class="form-group collapseWriteReview" data-toggle="popover">
#          <a href="#">
#           <span class="spr-reviews">
#           </span>
#           <span>
#            Review
#            <b class="caret">
#            </b>
#           </span>
#          </a>
#         </div>
#        </li>
#        <!-- NEW: added ID for easier control and override -->
#        <li class="search" id="search-menu">
#         <form action="/search.asp">
#          <div class="form-group">
#           <input id="q2" name="q" placeholder="Search" type="text" value=""/>
#           <input alt="Search" data-target=".navbar-collapse-search" data-toggle="collapse" src="/art/bs/icons/search.png" type="image"/>
#          </div>
#         </form>
#        </li>
#        <li class="join">
#         <a href="https://www.makeupalley.com/account/join.asp" onclick="ga('send', {hitType: 'event',eventCategory: 'Internal Link',eventAction: 'Join',eventLabel: 'Nav'});">
#          Join
#         </a>
#        </li>
#        <li class="divider-vertical">
#         <span>
#          |
#         </span>
#        </li>
#        <li class="login">
#         <a href="https://www.makeupalley.com/account/login.asp" onclick="ga('send', {hitType: 'event',eventCategory: 'Internal Link',eventAction: 'Login',eventLabel: 'Nav'});">
#          Login
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-12">
#      <ol class="breadcrumb">
#       <li class="hidden-xs" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a class="track_BreadCrumbs_Home" href="/" itemprop="url">
#         <span class="hidden-xs" itemprop="title">
#          Home
#         </span>
#        </a>
#       </li>
#       <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a class="track_BreadCrumbs_ProuctReviews" href="/product/" itemprop="url">
#         <span itemprop="title">
#          Product Reviews
#         </span>
#        </a>
#       </li>
#       <li itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a class="track_BreadCrumbs_Category" href="/product/searching.asp/CategoryID=709/category=Neck%2FDecollete+Cream/" itemprop="url">
#         <span itemprop="title">
#          Neck/Decollete Cream
#         </span>
#        </a>
#       </li>
#       <li class="last-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a class="track_BreadCrumbs_Brand" href="/product/searching.asp/Brand=1694/brandname=StriVectin/" itemprop="url">
#         <span itemprop="title">
#          StriVectin
#         </span>
#        </a>
#       </li>
#      </ol>
#     </div>
#     <div class="col-md-12">
#      <div class="leaderboard">
#       <!-- ResponsiveLeaderboard responsiveleaderboard-->
#       <div class="responsiveleaderboard">
#        <div id="REVIEWS_ATF-0">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-12">
#      <div class="visible-xs" id="sticky-button">
#       <a data-label="Responsive" href="/product/qu.asp?itemid=151441" onclick="ga('send', {hitType: 'event',eventCategory: 'WriteAReview',eventAction: 'WriteAReview',eventLabel: 'FlatingButton'});">
#        <span class="fa-stack fa-2x">
#         <i class="fa icon-circle fa-stack-2x" style="color:#994466">
#         </i>
#         <i class="fa icon-pencil fa-stack-1x fa-inverse">
#         </i>
#        </span>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="row " id="main">
#     <div class="col-sm-7 col-md-8 limit-left">
#      <div>
#       <h1>
#        StriVectin TL Tightening Neck Cream
#       </h1>
#       <div id="product-details">
#        <div class="product">
#         <div class="row clearfix top-devider bottom-devider">
#          <div class="col-md-8 h-devider">
#           <div class="row">
#            <div class="product-image product-detail-image">
#             <a data-lightbox="images" data-title="StriVectin TL Tightening Neck Cream" href="https://img.makeupalley.com/0/2/6/2/2336028.JPG" onclick="ga('send', {hitType: 'event',eventCategory: 'Ajax Interaction',eventAction: 'Zoom Image',eventLabel: ''});">
#              <img alt="StriVectin TL Tightening Neck Cream" height="250" src="https://img.makeupalley.com/0/2/6/2/2336028.JPG" width="250"/>
#             </a>
#            </div>
#           </div>
#           <div class="row">
#            <div class="product-thumbs">
#            </div>
#           </div>
#           <script type="application/ld+json">
#            {  "@context": "http://schema.org/",		   "@type": "AggregateRating",  "ratingValue": "2.6",	"ratingCount": "19",	"itemReviewed": {	 	"@type": "Product",    "name": "StriVectin TL Tightening Neck Cream"	   ,"image": "https://img.makeupalley.com/0/2/6/2/2336028.JPG"	 }  }
#           </script>
#           <div class="product-review visible-xs-block">
#            <p>
#             <a data-label="ResponsiveSmall" href="/product/x_qu.asp?itemid=151441" onclick="ga('send', {hitType: 'event',eventCategory: 'WriteAReview',eventAction: 'WriteAReview',eventLabel: 'ResponsiveSmall'});">
#              WRITE A REVIEW
#             </a>
#            </p>
#           </div>
#           <div class="row visible-xs-block">
#            <div class="social">
#             <div class="pin">
#              <a href="https://pinterest.com/pin/create/button/?url=&amp;media=image&amp;description=https%3A%2F%2Fimg.makeupalley.com%2F0%2F2%2F6%2F2%2F2336028.JPG" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Pinterest Mobile',eventLabel: ''});" target="_blank">
#               <span class="spr-icon-pin" title="Pinterest">
#               </span>
#              </a>
#             </div>
#             <div class="googleplus">
#              <a href="https://plus.google.com/share?url=" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Google Mobile',eventLabel: ''});" target="_blank">
#               <span class="spr-icon-g" title="Google">
#               </span>
#              </a>
#             </div>
#             <div class="fb">
#              <a href="https://www.facebook.com/sharer/sharer.php?u=" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Facebook Mobile',eventLabel: ''});" target="_blank">
#               <span class="spr-icon-fb" title="Facebook">
#               </span>
#              </a>
#             </div>
#             <div class="tw">
#              <a href="https://twitter.com/home?status=StriVectin+TL+Tightening+Neck+Cream+reviews%2C+photo%2C+ingredients++%2D+Makeupalley " onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Twitter Mobile',eventLabel: ''});" target="_blank">
#               <span class="spr-icon-tw" title="Twitter">
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="col-sm-12 col-md-4">
#           <div class="product-review-stats tablet-divider">
#            <div class="col-md-12 col-sm-6 col-xs-6 y-divider">
#             <h3>
#              2.6
#             </h3>
#             <span class="l-2-6">
#             </span>
#             <p>
#              <span>
#               19
#              </span>
#              reviews
#             </p>
#             <p>
#              36% would repurchase
#             </p>
#             <p class="pack">
#              Package Quality: 2.8
#             </p>
#             <p class="price">
#              Price: $$$
#             </p>
#             <div aria-hidden="true" class="modal" id="ItemId">
#              151441
#             </div>
#             <div aria-hidden="true" class="modal" id="ItemType">
#              4
#             </div>
#             <div aria-hidden="true" class="modal" id="UPCs">
#              810907020496 817777003796 817777004250 817777005080 817777007923
#             </div>
#             <div aria-hidden="true" class="modal" id="KeyWords">
#              StriVectin TL Tightening Neck Cream
#             </div>
#             <div aria-hidden="true" class="modal" id="ProductName">
#              TL Tightening Neck Cream
#             </div>
#             <div aria-hidden="true" class="modal" id="FetchOffers">
#              0
#             </div>
#             <div aria-hidden="true" class="modal" id="TrackLinks">
#              1
#             </div>
#            </div>
#            <div class="col-md-12 col-sm-6 col-xs-6">
#             <div class="product-review hidden-xs">
#              <p>
#               <a data-label="Responsive" href="/product/qu.asp?itemid=151441" onclick="ga('send', {hitType: 'event',eventCategory: 'WriteAReview',eventAction: 'WriteAReview',eventLabel: 'Responsive'});">
#                WRITE A REVIEW
#               </a>
#              </p>
#             </div>
#             <p class="pack-xs">
#              Package Quality: 2.8
#             </p>
#             <p class="price-xs">
#              Price: $$$
#             </p>
#             <div class="product-ingredients">
#              <p data-target="#ingredientsModal" data-toggle="modal">
#               INGREDIENTS
#              </p>
#              <span id="hold-ingredients">
#               Water (Aqua), Butyrospermum Parkii (Shea Butter), Myristyl Nicotinate, Isononyl Isononanoate, Caprylic/Capric Triglyceride, Glycerin, C12-15 Alkyl Benzoate, Butylene Glycol, Glyceryl Stearate, Cetearyl Alcohol, PEG-100 Stearate, PPG-3 Benzyl Ether Myristate, Dimethicone, Ethylene/Acrylic Acid Copolymer, Pentylene Glycol, Polyacrylamide, Sodium Polystyrene Sulfonate, Sorghum Bicolor Stalk Juice, Tetrapeptide-21, Pullulan, Algae Extract, Cyathea Cumingii Leaf Extract, Lepidium Sativum Sprout Extract, Malus Domestica Fruit Cell Culture Extract, Xanthium Sibiricum Fruit Extract, Lonicera Japonica (Honeysuckle) Flower Extract, Cyperus Rotundus Root Extract, Behenyl Alcohol, Steareth-2, Panthenol, Hydrolyzed Hyaluronic Acid, Ceramide 2, Lecithin, C13-14 Isoparaffin, Laureth-7, Xanthan Gum, Acrylates/C10-30 Alkyl Acrylate Crosspolymer, Sodium Hydroxide, BHT, Tetrasodium EDTA, Sorbic Acid, Caprylyl Glycol, Benzoic Acid, Chlorphenesin, Phenoxyethanol, Methyldihydrojasmonate, Citrus Aurantium Dulcis, Citrus Medica Limonum (Lemon) Fruit Extract, Benzyl Alcohol, Dipropylene Glycol, Hexamethylindanopyran, Ethyl Linalool, Limonene
#              </span>
#             </div>
#             <div class="row hidden-xs">
#              <div class="social">
#               <div class="pin">
#                <a href="https://pinterest.com/pin/create/button/?url=https%3A%2F%2Fwww.makeupalley.com%2Fproduct%2Fshowreview.asp%2FItemId%3D1%351441%2FTL-Tightening-Neck-Cream%2FStriVectin%2FNeck%2FDecollete-Cream&amp;media=image&amp;description=https%3A%2F%2Fimg.makeupalley.com%2F0%2F2%2F6%2F2%2F2336028.JPG" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Pinterest',eventLabel: ''});" target="_blank">
#                 <span class="spr-icon-pin" title="Pinterest">
#                 </span>
#                </a>
#               </div>
#               <div class="googleplus">
#                <a href="https://plus.google.com/share?url=https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Google',eventLabel: ''});" target="_blank">
#                 <span class="spr-icon-g" title="Google">
#                 </span>
#                </a>
#               </div>
#               <div class="fb">
#                <a href="https://www.facebook.com/sharer/sharer.php?u=https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Facebook',eventLabel: ''});" target="_blank">
#                 <span class="spr-icon-fb" title="Facebook">
#                 </span>
#                </a>
#               </div>
#               <div class="tw">
#                <a href="https://twitter.com/home?status=StriVectin TL Tightening Neck Cream reviews, photo, ingredients  - Makeupalley https://www.makeupalley.com/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream" onclick="ga('send', {hitType: 'event',eventCategory: 'Social Share',eventAction: 'Twitter',eventLabel: ''});" target="_blank">
#                 <span class="spr-icon-tw" title="Twitter">
#                 </span>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="row clearfix">
#          <div class="col-md-12">
#           <div class="product-reformulation">
#            <a href="/brand/StriVectin/Brand=1694/">
#             StriVectin reviews, photos and discussion
#            </a>
#           </div>
#           <hr class="custom-hr hidden-xs"/>
#           <div class="mobile-where-to-buy visible-xs">
#           </div>
#           <div class="mobile-where-to-swap visible-xs">
#           </div>
#           <hr class="custom-hr visible-xs-block"/>
#           <div class="panel-group visible-xs-block" id="accordion_filters">
#            <div class="panel panel-default">
#             <div class="panel-heading">
#              <h4 class="panel-title">
#               <a data-parent="#accordion_filters" data-toggle="collapse" href="#collapseOne">
#                FILTERS
#                <b class="caret">
#                </b>
#               </a>
#              </h4>
#             </div>
#             <div class="panel-collapse collapse" id="collapseOne">
#              <div class="panel-body">
#               <div class="product-filter">
#                <ul class="nav nav-pills">
#                 <li class="dropdown" id="dropdown-skintonetype">
#                  <p>
#                   Filter by skin/hair/eye
#                  </p>
#                  <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#                   <span>
#                    All
#                   </span>
#                   <b class="caret">
#                   </b>
#                  </a>
#                  <ul class="dropdown-menu">
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=-2/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     All
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=-1/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Skin Tone
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=0/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Other
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=1/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Fair
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=2/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Fair-Medium
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=3/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Medium
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=5/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Olive
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=7/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Medium Brown
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=99/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Skin Type
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=100/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Other
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=101/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Very Dry
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=102/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Dry
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=104/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Combination
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=105/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Acne-prone
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=107/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Very Oily
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=108/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Sensitive
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=199/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Hair Type
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=200/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Other
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=201/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Straight
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=202/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Wavy
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=203/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Curly
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=299/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Eye Color
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=301/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Blue
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=302/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Brown
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=303/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Black
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=304/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Hazel
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=306/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Green
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/skintonetype=307/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     ... Gray
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="dropdown" id="dropdown-AgeRange">
#                  <p>
#                   Filter by age
#                  </p>
#                  <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#                   <span>
#                    All
#                   </span>
#                   <b class="caret">
#                   </b>
#                  </a>
#                  <ul class="dropdown-menu">
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=0/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Age Range
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=3/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     25-29
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=4/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     30-35
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=5/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     36-43
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=6/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     44-55
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/AgeRange=7/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     56 &amp; Over
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="dropdown" id="dropdown-SortBy">
#                  <p>
#                   Sort By
#                  </p>
#                  <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#                   <span>
#                    Date
#                   </span>
#                   <b class="caret">
#                   </b>
#                  </a>
#                  <ul class="dropdown-menu">
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/SortBy=helpful/AgeRange=/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Most Helpful
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/SortBy=rating-desc/AgeRange=/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Rating (Highest first)
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/SortBy=rating-asc/AgeRange=/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Rating (Lowest first)
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/SortBy=date-desc/AgeRange=/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Date
#                    </a>
#                   </li>
#                   <li class="divider">
#                   </li>
#                   <li>
#                    <a href="/product/showreview.asp/ItemId=151441/SortBy=date-asc/AgeRange=/SkinToneType=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                     Date (Oldest first)
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="product-filter hidden-xs">
#            <ul class="nav nav-pills">
#             <li class="dropdown" id="mobile-dropdown-skintonetype">
#              <p>
#               Filter by skin/hair/eye
#              </p>
#              <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#               <span>
#                All
#               </span>
#               <b class="caret">
#               </b>
#              </a>
#              <ul class="dropdown-menu">
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=-2/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 All
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=-1/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 Skin Tone
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=0/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Other
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=1/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Fair
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=2/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Fair-Medium
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=3/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Medium
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=5/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Olive
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=7/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Medium Brown
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=99/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 Skin Type
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=100/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Other
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=101/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Very Dry
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=102/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Dry
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=104/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Combination
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=105/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Acne-prone
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=107/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Very Oily
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=108/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Sensitive
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=199/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 Hair Type
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=200/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Other
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=201/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Straight
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=202/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Wavy
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=203/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Curly
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=299/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 Eye Color
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=301/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Blue
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=302/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Brown
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=303/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Black
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=304/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Hazel
#                </a>
#               </li>
#               <li class="divider">
#               </li>
#               <li>
#                <a href="/product/showreview.asp/ItemId=151441/skintonetype=306/AgeRange=/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream">
#                 ... Green
#                </a>
#               </li>
#               <li class="divider">
#               </li>
# ...
#          Best Korean Skincare Products
#         </a>
#        </li>
#        <li>
#         <a href="/user/favorites/bestofmakeupalley-best-foundations-for-summer" onclick="ga('send', {hitType: 'event',eventCategory: 'Internal Link',eventAction: 'Curated Favorites Lists',eventLabel: 'Click'});">
#          Best Foundations For Summer
#         </a>
#        </li>
#        <li>
#         <a href="/user/favorites/bestofmakeupalley-best-retinols-for-all-skins" onclick="ga('send', {hitType: 'event',eventCategory: 'Internal Link',eventAction: 'Curated Favorites Lists',eventLabel: 'Click'});">
#          Best Retinols for All Skins
#         </a>
#        </li>
#        <li>
#         <a href="/user/favorites/bestofmakeupalley-best-natural-beauty-products" onclick="ga('send', {hitType: 'event',eventCategory: 'Internal Link',eventAction: 'Curated Favorites Lists',eventLabel: 'Click'});">
#          Best Natural Beauty Products
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div id="stickyBanner">
#       <br/>
#       <div id="REVIEWS_BTF-3">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row ">
#    </div>
#    <div class="row back-to-top">
#     <div class="col-sm-12 col-md-12">
#      <a href="#top">
#       <img alt="Back to Top" height="14" src="/art/bs/icons/back-to-top.png" width="24"/>
#      </a>
#     </div>
#    </div>
#    <footer class="bs-docs-footer">
#     <div class="container">
#      <ul>
#       <li>
#        <a href="/content/content.asp/s=0/c=DMCA/">
#         DMCA
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/content/content.asp/s=0/c=TermsOfService/">
#         Terms of Use
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/content/content.asp/s=0/c=PrivacyPolicy/">
#         Privacy Policy
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/content/content.asp/s=0/c=AboutUs/">
#         About Us
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/faq/">
#         FAQ
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/links/">
#         Links
#        </a>
#       </li>
#       <li>
#        |
#       </li>
#       <li>
#        <a href="/docs/contact.asp">
#         Contact Us
#        </a>
#       </li>
#      </ul>
#      <p>
#       Copyright ©2018 MakeupAlley.com. All rights reserved. MakeupAlley™ is a registered trademark of MUA, Inc.
#      </p>
#      <span class="stats">
#       Server Time 1/27/2019 2:07:10 PM EST ms
#      </span>
#     </div>
#    </footer>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="favoritePick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelFav">
#        Favorite
#       </h3>
#      </div>
#      <div class="modal-body">
#       <p>
#        Add Favorite
#       </p>
#       <div class="form-group">
#       </div>
#       <div class="modal-status">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" id="addFavorite" type="submit">
#        ADD
#       </button>
#       <button class="btn btn-default pull-right closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="uploadPhoto" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelPhoto hidden-xs">
#        Insert photo
#       </h3>
#       <h3 class="modalLabelPhoto visible-xs">
#        Add photo
#       </h3>
#       <ul class="nav nav-tabs" id="tabMenu" role="tablist">
#        <li class="active">
#         <a data-toggle="tab" href="#uploadPic" id="uploadPicTab" role="tab">
#          Upload photo
#         </a>
#        </li>
#        <li>
#         <a data-toggle="tab" href="#addPic" id="addPhotoTab" role="tab">
#          Add photo
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="modal-body">
#       <div class="form-group">
#        <div class="tab-content">
#         <div class="tab-pane active" id="uploadPic">
#          <div class="photo-wrapper">
#           <div id="selectFiles">
#            <form action="/product/myreviewimages.asp" enctype="multipart/form-data" id="uploadForm" method="post">
#             <input id="ItemIdForPic" name="ItemIdForPic" type="hidden"/>
#             <input id="Type" name="Type" type="hidden" value="1"/>
#             <input id="ajax" name="ajax" type="hidden" value="1"/>
#             <input class="hide" id="FILE1" name="FILE1" type="file"/>
#            </form>
#            <button class="btn btn-primary pull-left primaryBtnModal hidden-xs trigger-file" type="button">
#             Select files from your computer
#            </button>
#            <button class="btn btn-primary pull-left primaryBtnModal visible-xs trigger-file" type="button">
#             Select photos
#            </button>
#           </div>
#           <span class="filename">
#           </span>
#          </div>
#         </div>
#         <div class="tab-pane fade" id="addPic">
#          <div class="modal-status">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" id="uploadFile" type="submit">
#        UPLOAD
#       </button>
#       <button class="btn btn-default pull-left closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="upcPick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelUpc">
#        UPC code
#       </h3>
#      </div>
#      <div class="modal-body">
#       <p class="current-num">
#       </p>
#       <div class="form-group">
#        <label for="inputField">
#         Add another
#        </label>
#        <input class="form-control" id="inputField" placeholder="Enter UPC code" type="text"/>
#       </div>
#       <div class="loading">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" type="submit">
#        ADD
#       </button>
#       <button class="btn btn-default pull-right closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="discontinuedPick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelDisc">
#        Discontinued
#       </h3>
#      </div>
#      <div class="modal-body">
#       <p>
#        Are you sure this product is discontinued?
#       </p>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" id="discontinuedSubmit" type="submit">
#        OK
#       </button>
#       <button class="btn btn-default pull-right closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="errorPick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelErr">
#        Report error
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="form-group upper">
#        <label for="inputProductName">
#         Update product name
#         <span>
#          (Please update with care)
#         </span>
#        </label>
#        <input class="form-control" id="inputProductName" placeholder="Product name" type="text"/>
#       </div>
#       <div class="upper-button-wrapper">
#        <button class="btn btn-primary pull-left primaryBtnModal" id="btnProductName" type="submit">
#         SEND
#        </button>
#        <button class="btn btn-default pull-left closeModal" data-dismiss="modal" type="button">
#         CANCEL
#        </button>
#       </div>
#       <div class="loading">
#       </div>
#       <hr/>
#       <div class="form-group lower">
#        <label for="areaInput">
#         Message Us about other errors
#        </label>
#        <textarea class="form-control" id="areaInput" placeholder="Please enter the message" rows="4"></textarea>
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" id="btnReportError" type="submit">
#        SEND
#       </button>
#       <button class="btn btn-default pull-left closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="thanksPick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelThx">
#        Thank You
#       </h3>
#      </div>
#      <div class="modal-body">
#       <b>
#        Your favorite has been updated
#       </b>
#       <p>
#        daasfdsad, asdadasd, addasdasdas, asdasdasdasfsdfgdfs, fgdssdgfdgfg, gfgdgdfgdhfgj
#       </p>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left closeModal" data-dismiss="modal" type="button">
#        CLOSE
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="flagPick" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3 class="modalLabelUpc">
#        Please Flag with Care
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="flag-reasons">
#        <p>
#         <a data-id="11">
#          Reviewer did not try the product
#         </a>
#         <br/>
#         <a data-id="12">
#          Profanity/Vulgar language
#         </a>
#         <br/>
#         <a data-id="13">
#          Advertising (Vendor promotion, iHerb Coupons etc.)
#         </a>
#         <br/>
#         <a data-id="14">
#          Marketing campaign (BzzAgent, Influenster etc.)
#         </a>
#        </p>
#       </div>
#       <div class="modal-status">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-default pull-right closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade" id="ingredientsModal" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <span aria-hidden="true" class="spr-close-btn close" data-dismiss="modal">
#       </span>
#       <h3>
#        Ingredients
#       </h3>
#      </div>
#      <div class="modal-body">
#       <button class="btn btn-default button-padding edit-ingred" type="button">
#        Edit
#       </button>
#       <div id="ingredientsContent">
#       </div>
#       <div class="modal-status">
#       </div>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary pull-left primaryBtnModal" type="button">
#        SAVE
#       </button>
#       <button class="btn btn-default pull-right closeModal" data-dismiss="modal" type="button">
#        CANCEL
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- NEW: collapse elements - reviews/post -->
#   <!--[if lt IE 9]>      <script>b=1;</script>    <![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');	ga('set', 'dimension1', '');	ga('create', 'UA-108197-1', 'auto');	ga('send', 'pageview');	ga('create', 'UA-108197-16', 'auto','rollup');	ga('rollup.send', 'pageview');	/*dfp.17.js*/var aAdUnits;var sAllAdUnits='HOMEPAGE_ATF-0,HOMEPAGE_ATF-1,HOMEPAGE_BTF-2,MESSAGE_BOARDS_ATF-1,MESSAGE_BOARDS_BTF-2,MESSAGE_BOARDS_BTF-3,MESSAGE_BOARDS_BTF-10,MESSAGE_BOARDS_BTF-20,REVIEWS_ATF-0,REVIEWS_ATF-1,REVIEWS_BTF-2,REVIEWS_BTF-3,REVIEWS_2_ATF-0,REVIEWS_2_ATF-1,REVIEWS_2_BTF-2,REVIEWS_2_BTF-3,REVIEWS_2_BTF-4,ROS_ATF-0,ROS_ATF-1,ROS_BTF-2,ROS_BTF-3,ROS_ATF-4,ROS_BTF-5,Mobile_Other_ATF_Banner,Mobile_ATF_Reviews2_Banner-1,Mobile_Homepage_ATF_Banner-0';var aAllAdUnits=sAllAdUnits.split(',');function in_array(needle,haystack){for(var i=0,maxi=haystack.length;i<maxi;++i){if(haystack[i]==needle){return!0}}return!1}function DisplayNow(){googletag.pubads().enableSingleRequest();googletag.enableServices();for(var sAdUnit in aAllAdUnits){if(in_array(aAllAdUnits[sAdUnit],aAdUnits)==!0){googletag.display(aAllAdUnits[sAdUnit])}}}var googletag=googletag||{};googletag.cmd=googletag.cmd||[];(function(){var gads=document.createElement('script');gads.async=!0;gads.type='text/javascript';var useSSL='https:'==document.location.protocol;gads.src=(useSSL?'https:':'http:')+'//www.googletagservices.com/tag/js/gpt.js';var node=document.getElementsByTagName('script')[0];node.parentNode.insertBefore(gads,node)})();googletag.cmd.push(function(){console.log('creating units');var leaderboardMapping=googletag.sizeMapping().addSize([1,1],[[320,100],[320,50],[300,50]]).addSize([600,200],[468,60]).addSize([750,200],[728,90]).addSize([1050,200],[[970,90],[728,90]]).build();var midContentMapping=googletag.sizeMapping().addSize([1,1],[[320,50],[300,50]]).addSize([600,200],[468,60]).build();var midContentWideMapping=googletag.sizeMapping().addSize([1,1],[[300,250],[320,50],[300,50]]).addSize([340,200],[[336,280],[300,250]]).addSize([600,200],[468,60]).addSize([1200,200],[728,90]).build();var squareMapping=googletag.sizeMapping().addSize([1,1],[[300,250],[250,250]]).addSize([1050,200],[336,280]).build();var towerMapping=googletag.sizeMapping().addSize([1,1],[[320,50],[300,50],[300,250],[250,250]]).addSize([600,200],[160,600]).build();var halfpageMapping=googletag.sizeMapping().addSize([1,1],[300,250]).addSize([1050,200],[300,600]).build();var flexHalfpageMapping=googletag.sizeMapping().addSize([1,1],[300,250]).addSize([1050,200],[[300,250],[300,600]]).build();var smallLeaderboardMapping=googletag.sizeMapping().addSize([1,1],[[320,100],[320,50],[300,50]]).addSize([600,200],[468,60]).addSize([750,200],[728,90]).build();var tinyLeaderboardMapping=googletag.sizeMapping().addSize([1,1],[[320,100],[320,50],[300,50]]).build();var horizontalLeftColumnMapping=googletag.sizeMapping().addSize([1,1],[[320,100],[320,50],[300,50]]).addSize([600,200],[468,60]).addSize([1280,200],[728,90]).build();aAdUnits=sDFPAds.split(',');if(in_array('HOMEPAGE_ATF-0',aAdUnits)==!0){googletag.defineSlot('/1004341/HOMEPAGE_ATF',[],'HOMEPAGE_ATF-0').defineSizeMapping(leaderboardMapping).addService(googletag.pubads())}if(in_array('HOMEPAGE_ATF-1',aAdUnits)==!0){googletag.defineSlot('/1004341/HOMEPAGE_ATF',[[300,250],[300,600]],'HOMEPAGE_ATF-1').defineSizeMapping(flexHalfpageMapping).addService(googletag.pubads())}if(in_array('HOMEPAGE_BTF-2',aAdUnits)==!0){googletag.defineSlot('/1004341/HOMEPAGE_BTF',[],'HOMEPAGE_BTF-2').defineSizeMapping(midContentMapping).addService(googletag.pubads())}if(in_array('MESSAGE_BOARDS_ATF-0',aAdUnits)==!0)googletag.defineSlot('/1004341/MESSAGE_BOARDS_ATF',[],'MESSAGE_BOARDS_ATF-0').defineSizeMapping(smallLeaderboardMapping).addService(googletag.pubads());if(in_array(' ...
#   </script>
#  </body>
# </html>

# %%
# there are 2 types of html items that we want to remember: elements/tags and attributes
# an element has a start tag and end tag eg. title
# sometimes it wont have an explicit end tag but just a '/'
# elements sometimes have attributes. most popular is the href attribute to denote a link
# usually comes in the form of name='value'
# common attributes: href, id, class

# %%
# inspect product name, it's in the element <h1>

# %%
name_list = soup.find_all('h1')

# %%
name_list
# Out:
# [<h1><a class="track_Nav_Home" href="/"><img alt="MakeupAlley" class="discreet" height="51" src="/art/bs/Mua_Logo3x.png" width="247"/></a></h1>,
#  <h1>StriVectin TL Tightening Neck Cream</h1>]

# %%
# select() method offers more flexibility

name = soup.select('div#main h1')
# name2 = soup.select('div.col-sm-7 h1')

# tag2 doesnt have to be the direct tag/descendent of tag1

# %%
name
# Out:
# [<h1>StriVectin TL Tightening Neck Cream</h1>]

# %%
print(type(name[0]))
name[0].text
# Out:
# <class 'bs4.element.Tag'>
# 'StriVectin TL Tightening Neck Cream'

# %%
rating = soup.find('h3').text

# %%
rating
# Out:
# '2.6'

# %%
rating = soup.select('div.product-review-stats h3')

# %%
rating
# Out:
# [<h3>2.6</h3>]

# %%
rating[0].text
# Out:
# '2.6'

# %%
# what if the data we want is in an attribute?
# eg. getting links from href attribute is a popular task
brand_list = soup.find_all(class_ = "track_BreadCrumbs_Brand")
brand_href = brand_list[0].get('href')

# %%
brand_list
# Out:
# [<a class="track_BreadCrumbs_Brand" href="/product/searching.asp/Brand=1694/brandname=StriVectin/" itemprop="url"><span itemprop="title">StriVectin</span></a>]

# %%
brand_list[0].get('href')
# Out:
# '/product/searching.asp/Brand=1694/brandname=StriVectin/'

# %%
# for i in brand_list[0].children:
#     print(i)
#     print(i.get('itemprop'))
# #     for child in i:
# #         print(child)

# %%
# helper variables
base_url = 'https://www.makeupalley.com'
# have to use https because using http will make it default to the first review page
part_prod_link = '/product/showreview.asp/ItemId='
part_brand_link = '/product/searching.asp/Brand='


def go_link(link):
    r = requests.get(link)
    html_doc = r.text
    return BeautifulSoup(html_doc, "html5lib")

def go_prod(link):
    """
    Function go to each product link and get data
    :param link: string that represents the latter part of the link to product review pages
    :return: variables related to product reviews
    """

    soup = go_link(base_url+link)

    if len(soup.select('title')) == 0:
        pass
    else:
        # find users, characteristics and reviews; and ratings and dates
        users = soup.find_all(class_='user-name')
        user_list = [i.text for i in users]
        # dont have to go to each user and see how many reviews they have because we basically dont have a minimum for users

        chars = soup.find_all(class_='important')
        char_list = [i.text for i in chars]

        reviews = soup.find_all(class_='comment-content')
        review_list = [i.text for i in reviews]

        # find user rating/lipies for product
        lipies = soup.select('div.lipies span[class*="l-"]')
        # span is a tag, class is an attribute, choose only attribute with value starts with l-
        lipie_list = [i['class'][0] for i in lipies]
        
        # find review dates
        date = soup.select('div.date')
        # match either div.date or time tag
        date_list = [i.text for i in date]
        
        # number of reviews on each page
        n = len(user_list)


        # find name of product
        name_list = soup.find_all('h1')
        name = name_list[1].text
        name = [name] * n

        # find rating of product
        rating = soup.find('h3').text
        rating = [rating] * n

        repurchase = soup.find_all('p', string=re.compile('would repurchase'))[0].text
        repurchase = [repurchase] * n

        pkg_qual = soup.find_all('p', string=re.compile('Package Quality'))[0].text
        pkg_qual = [pkg_qual] * n

        price = soup.find_all('p', string=re.compile('Price'))[0].text
        price = [price] * n

        ingredient = soup.find_all(id='hold-ingredients')[0].text
        ingredient = [ingredient] * n

        # find brand of product
        brand_list = soup.find_all(class_ = "track_BreadCrumbs_Brand")
        brand = brand_list[0].text
        brand = [brand] * n


        return name, rating, repurchase, pkg_qual, price, ingredient, user_list, char_list, review_list, lipie_list, date_list, brand

# %%
a, b, c, d, e, f, g, h, k, l, m, n = go_prod('/product/showreview.asp/ItemId=151441/TL-Tightening-Neck-Cream/StriVectin/Neck/Decollete-Cream')

# %%
df = pd.DataFrame(
    {'names': a, 'ratings': b, 'repurchases': c
        , 'pkg_quals': d, 'prices': e, 'ingredients': f
        , 'brands': n
        , 'users': g, 'chars': h, 'reviews': k
        , 'lipies': l, 'dates': m})

# %%
df[:3]
# Out:
#                                  names ratings           repurchases  \
# 0  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
# 1  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
# 2  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
#
#               pkg_quals      prices  \
# 0  Package Quality: 2.8  Price: $$$
# 1  Package Quality: 2.8  Price: $$$
# 2  Package Quality: 2.8  Price: $$$
#
#                                          ingredients      brands  \
# 0  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
# 1  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
# 2  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
#
#                                       users  \
# 0  \t\t\t\t\t\t\t\tDmurphy431\t\t\t\t\t\t\t
# 1    \t\t\t\t\t\t\t\tLeslieCZ\t\t\t\t\t\t\t
# 2  \t\t\t\t\t\t\t\tnoBSbeauty\t\t\t\t\t\t\t
#
#                                                chars  \
# 0  \t\t\tAge: 56 & Over\t\t\tSkin: Other, Fair-Me...
# 1  \t\t\tAge: 56 & Over\t\t\tSkin: Very Dry, Fair...
# 2  \t\t\tAge: 25-29\t\t\tSkin: Dry, Fair-Medium, ...
#
#                                              reviews lipies  \
# 0  \t\t\t\t\t\t\tI should know that there is no s...  l-3-0
# 1  \t\t\t\t\t\t\tThis is similar to Revision Nect...  l-4-0
# 2  \t\t\t\t\t\t\tThere are several issues with th...  l-1-0
#
#                                      dates
# 0  \t\t\t\ton  12/30/2018 5:24:00 PM\t\t\t
# 1    \t\t\t\ton  5/1/2017 7:56:00 PM\t\t\t
# 2    \t\t\t\ton  4/7/2017 6:54:00 PM\t\t\t

# %% [markdown]
# # 2. Structure

# %%
# function to parse information from a page
# a wrapper of some sort to go through each of the review page of a product
# a function to collect all the products
# another helper function/wrapper to go through all pages

# %% [markdown]
# # 3. Checkpoints

# %%
# your code works and you're scraping along just fine. but what if your internet went
# down? or you forgot to set your computer not to go to sleep
# save your progress along the way. one way is to use a checkpoint package like pickle/dill
dill.dump(df, open('df.pkd', 'wb'))

# %%
df2 = dill.load(open('df.pkd', 'rb'))

# %%
df2[:3]
# Out:
#                                  names ratings           repurchases  \
# 0  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
# 1  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
# 2  StriVectin TL Tightening Neck Cream     2.6  36% would repurchase
#
#               pkg_quals      prices  \
# 0  Package Quality: 2.8  Price: $$$
# 1  Package Quality: 2.8  Price: $$$
# 2  Package Quality: 2.8  Price: $$$
#
#                                          ingredients      brands  \
# 0  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
# 1  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
# 2  Water (Aqua), Butyrospermum Parkii (Shea Butte...  StriVectin
#
#                                       users  \
# 0  \t\t\t\t\t\t\t\tDmurphy431\t\t\t\t\t\t\t
# 1    \t\t\t\t\t\t\t\tLeslieCZ\t\t\t\t\t\t\t
# 2  \t\t\t\t\t\t\t\tnoBSbeauty\t\t\t\t\t\t\t
#
#                                                chars  \
# 0  \t\t\tAge: 56 & Over\t\t\tSkin: Other, Fair-Me...
# 1  \t\t\tAge: 56 & Over\t\t\tSkin: Very Dry, Fair...
# 2  \t\t\tAge: 25-29\t\t\tSkin: Dry, Fair-Medium, ...
#
#                                              reviews lipies  \
# 0  \t\t\t\t\t\t\tI should know that there is no s...  l-3-0
# 1  \t\t\t\t\t\t\tThis is similar to Revision Nect...  l-4-0
# 2  \t\t\t\t\t\t\tThere are several issues with th...  l-1-0
#
#                                      dates
# 0  \t\t\t\ton  12/30/2018 5:24:00 PM\t\t\t
# 1    \t\t\t\ton  5/1/2017 7:56:00 PM\t\t\t
# 2    \t\t\t\ton  4/7/2017 6:54:00 PM\t\t\t

# %% [markdown]
# # 4. Scrape dynamic websites using Requests and Selenium

# %%
# useful websites
# http://stanford.edu/~mgorkove/cgi-bin/rpython_tutorials/Scraping_a_Webpage_Rendered_by_Javascript_Using_Python.php
# http://selenium-python.readthedocs.io/locating-elements.html
# https://stackoverflow.com/questions/22476112/using-chromedriver-with-selenium-python-ubuntu

from selenium import webdriver

# %%
# use special browser that Python can control
driver = webdriver.Chrome('/usr/lib/chromium-browser/chromedriver') 
#replace with .Firefox(), or with the browser of your choice
url_login = 'https://www.makeupalley.com/account/login.asp'
driver.get(url_login)

# %%
# log in
username = driver.find_element_by_id("UserName") #username form field
password = driver.find_element_by_id("Password") #password form field

# %%
# these are elements controled by Selenium/Python
username
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1f84f5ce23afec3515296fce3ae99c53", element="0.056409107606746556-1")>

# %%
password
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1f84f5ce23afec3515296fce3ae99c53", element="0.056409107606746556-2")>

# %%
# send username and password to the webpage
username.send_keys("testacount")
password.send_keys("password")

# %%
# click submit to login
submitButton = driver.find_element_by_id("login")
submitButton.click()

# %%
# set zoom level
driver.get('chrome://settings/')
driver.execute_script('chrome.settingsPrivate.setDefaultZoom(0.25);')

url = 'https://www.makeupalley.com'
driver.get(url)

driver.get('chrome://settings/')
driver.execute_script('chrome.settingsPrivate.setDefaultZoom(1);')

# %%
# with dynamic websites, sometimes you have to wait for all the elements to load
url = 'https://www.makeupalley.com'
driver.get(url)

time.sleep(5)
driver.get(demo_link)
